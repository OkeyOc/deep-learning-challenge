# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(['EIN', 'NAME'], axis=1, inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
num_value = application_df.dtypes.index.tolist()
application_df[num_value].nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_count = application_df["APPLICATION_TYPE"].value_counts()
app_type_count.head()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_count[app_type_count < 600].index)
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")
# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classify_count = application_df["CLASSIFICATION"].value_counts()
classify_count.head(15)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# Name: count, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classify_count = application_df["CLASSIFICATION"].value_counts(2)
classify_count
# Out:
# CLASSIFICATION
# C1000    0.505146
# C2000    0.177090
# C1200    0.141025
# C3000    0.055920
# C2100    0.054900
#            ...
# C4120    0.000029
# C8210    0.000029
# C2561    0.000029
# C4500    0.000029
# C2150    0.000029
# Name: proportion, Length: 71, dtype: float64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classify_count[classify_count < 300].index)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# Other    34299
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_df = pd.get_dummies(application_df)
numeric_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                    True
# 1           1    108590              1                   False
# 2           1      5000              0                   False
# 3           1      6692              1                   False
# 4           1    142590              1                   False
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                   False
# 34295       1      5000              0                   False
# 34296       1      5000              0                   False
# 34297       1      5000              1                   False
# 34298       1  36500179              0                   False
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     False                False                False
# 1                     False                 True                False
# 2                     False                False                False
# 3                     False                 True                False
# 4                     False                 True                False
# ...                     ...                  ...                  ...
# 34294                 False                False                 True
# 34295                 False                False                 True
# 34296                 False                 True                False
# 34297                 False                False                False
# 34298                 False                 True                False
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                    False                False                False  ...
# 1                    False                False                False  ...
# 2                     True                False                False  ...
# 3                    False                False                False  ...
# 4                    False                False                False  ...
# ...                    ...                  ...                  ...  ...
# 34294                False                False                False  ...
# 34295                False                False                False  ...
# 34296                False                False                False  ...
# 34297                 True                False                False  ...
# 34298                False                False                False  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                  False                   False                     False
# 1                   True                   False                     False
# 2                  False                   False                     False
# 3                  False                    True                     False
# 4                  False                   False                      True
# ...                  ...                     ...                       ...
# 34294              False                   False                     False
# 34295              False                   False                     False
# 34296              False                   False                     False
# 34297              False                   False                     False
# 34298              False                   False                     False
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                   False             False                   False
# 1                   False             False                   False
# 2                   False             False                   False
# 3                   False             False                   False
# 4                   False             False                   False
# ...                   ...               ...                     ...
# 34294               False             False                   False
# 34295               False             False                   False
# 34296               False             False                   False
# 34297               False             False                   False
# 34298               False              True                   False
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                False              False                      True
# 1                False              False                      True
# 2                False              False                      True
# 3                False              False                      True
# 4                False              False                      True
# ...                ...                ...                       ...
# 34294            False              False                      True
# 34295            False              False                      True
# 34296            False              False                      True
# 34297            False              False                      True
# 34298            False              False                      True
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 34294                     False
# 34295                     False
# 34296                     False
# 34297                     False
# 34298                     False
#
# [34299 rows x 38 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numeric_df["IS_SUCCESSFUL"]
x = numeric_df.drop(["IS_SUCCESSFUL"],axis=1)
# Split the preprocessed data into a training and testing dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=78)
x_train, x_test, y_train, y_test
# Out:
# (       STATUS   ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T19  \
#  30531       1      5000                   False                 False
#  22775       1      5000                   False                 False
#  19057       1      5000                   False                 False
#  27536       1      5000                   False                 False
#  21331       1  11121098                   False                 False
#  ...       ...       ...                     ...                   ...
#  20558       1     51827                   False                 False
#  18547       1     55178                   False                 False
#  3476        1    103405                   False                 False
#  22633       1      5000                   False                 False
#  16854       1   1869240                   False                 False
#
#         APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
#  30531                False                False                False
#  22775                 True                False                False
#  19057                 True                False                False
#  27536                 True                False                False
#  21331                 True                False                False
#  ...                    ...                  ...                  ...
#  20558                 True                False                False
#  18547                 True                False                False
#  3476                 False                False                 True
#  22633                 True                False                False
#  16854                 True                False                False
#
#         APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  ...  \
#  30531                 True                False                False  ...
#  22775                False                False                False  ...
#  19057                False                False                False  ...
#  27536                False                False                False  ...
#  21331                False                False                False  ...
#  ...                    ...                  ...                  ...  ...
#  20558                False                False                False  ...
#  18547                False                False                False  ...
#  3476                 False                False                False  ...
#  22633                False                False                False  ...
#  16854                False                False                False  ...
#
#         INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
#  30531              False                   False                     False
#  22775              False                   False                     False
#  19057              False                   False                     False
#  27536              False                   False                     False
#  21331              False                   False                     False
#  ...                  ...                     ...                       ...
#  20558              False                   False                      True
#  18547              False                   False                      True
#  3476               False                   False                     False
#  22633              False                   False                     False
#  16854              False                   False                     False
#
#         INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
#  30531               False             False                   False
#  22775               False             False                   False
#  19057               False             False                   False
#  27536               False             False                   False
#  21331                True             False                   False
#  ...                   ...               ...                     ...
#  20558               False             False                   False
#  18547               False             False                   False
#  3476                False             False                    True
#  22633               False             False                   False
#  16854                True             False                   False
#
#         INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
#  30531            False              False                      True
#  22775            False              False                      True
#  19057            False              False                      True
#  27536            False              False                      True
#  21331            False              False                      True
#  ...                ...                ...                       ...
#  20558            False              False                      True
#  18547            False              False                      True
#  3476             False              False                      True
#  22633            False              False                      True
#  16854            False              False                      True
#
#         SPECIAL_CONSIDERATIONS_Y
#  30531                     False
#  22775                     False
#  19057                     False
#  27536                     False
#  21331                     False
#  ...                         ...
#  20558                     False
#  18547                     False
#  3476                      False
#  22633                     False
#  16854                     False
#
#  [25724 rows x 37 columns],
#         STATUS  ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T19  \
#  13532       1    14651                   False                 False
#  24789       1  5144674                   False                 False
#  28401       1     5000                   False                 False
#  26471       1   855441                   False                 False
#  8873        1     5000                   False                 False
#  ...       ...      ...                     ...                   ...
#  17130       1     5000                   False                 False
#  4820        1     5000                   False                 False
#  3671        1     5000                   False                 False
#  20254       1     5000                   False                 False
#  20683       1     5000                   False                 False
#
#         APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
#  13532                 True                False                False
#  24789                 True                False                False
#  28401                 True                False                False
#  26471                 True                False                False
#  8873                  True                False                False
#  ...                    ...                  ...                  ...
#  17130                 True                False                False
#  4820                  True                False                False
#  3671                 False                False                False
#  20254                 True                False                False
#  20683                 True                False                False
#
#         APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  ...  \
#  13532                False                False                False  ...
#  24789                False                False                False  ...
#  28401                False                False                False  ...
#  26471                False                False                False  ...
#  8873                 False                False                False  ...
#  ...                    ...                  ...                  ...  ...
#  17130                False                False                False  ...
#  4820                 False                False                False  ...
#  3671                  True                False                False  ...
#  20254                False                False                False  ...
#  20683                False                False                False  ...
#
#         INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
#  13532              False                   False                     False
#  24789              False                   False                     False
#  28401              False                   False                     False
#  26471              False                   False                     False
#  8873               False                   False                     False
#  ...                  ...                     ...                       ...
#  17130              False                   False                     False
#  4820               False                   False                     False
#  3671               False                   False                     False
#  20254              False                   False                     False
#  20683              False                   False                     False
#
#         INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
#  13532               False             False                    True
#  24789               False             False                   False
#  28401               False             False                   False
#  26471               False              True                   False
#  8873                False             False                   False
#  ...                   ...               ...                     ...
#  17130               False             False                   False
#  4820                False             False                   False
#  3671                False             False                   False
#  20254               False             False                   False
#  20683               False             False                   False
#
#         INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
#  13532            False              False                      True
#  24789            False               True                      True
#  28401            False              False                      True
#  26471            False              False                      True
#  8873             False              False                      True
#  ...                ...                ...                       ...
#  17130            False              False                      True
#  4820             False              False                      True
#  3671             False              False                      True
#  20254            False              False                      True
#  20683            False              False                      True
#
#         SPECIAL_CONSIDERATIONS_Y
#  13532                     False
#  24789                     False
#  28401                     False
#  26471                     False
#  8873                      False
#  ...                         ...
#  17130                     False
#  4820                      False
#  3671                      False
#  20254                     False
#  20683                     False
#
#  [8575 rows x 37 columns],
#  30531    0
#  22775    0
#  19057    0
#  27536    1
#  21331    1
#          ..
#  20558    1
#  18547    0
#  3476     1
#  22633    0
#  16854    1
#  Name: IS_SUCCESSFUL, Length: 25724, dtype: int64,
#  13532    0
#  24789    0
#  28401    1
#  26471    0
#  8873     1
#          ..
#  17130    0
#  4820     0
#  3671     0
#  20254    0
#  20683    1
#  Name: IS_SUCCESSFUL, Length: 8575, dtype: int64)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(x_train)

# Scale the data
X_train_scaled = X_scaler.transform(x_train)
X_test_scaled = X_scaler.transform(x_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 9
hidden_nodes_layer2 = 18
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                